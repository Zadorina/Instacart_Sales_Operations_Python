# %%
import pandas as pd
import numpy as np
import os

# %%
# df = pd.read_csv(r'C:\Users\Anna\Desktop\Data Analytics\Instacart Basket Analysis\2 Data\Original Data\ orders.csv', index_col = False)

# %%
path = r'C:\Users\Anna\Desktop\Data Analytics\Instacart Basket Analysis\2 Data'

# %%
df = pd.read_csv(os.path.join(path, 'Original Data', 'orders.csv'), index_col = False)

# %%
df.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
df.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df = pd.read_csv(r'C:\Users\Anna\Desktop\Data Analytics\Instacart Basket Analysis\2 Data\Original Data\products.csv', index_col = False)

# %%
path = r'C:\Users\Anna\Desktop\Data Analytics\Instacart Basket Analysis\2 Data\Original Data'

# %%
df = pd.read_csv(os.path.join(path, 'products.csv'), index_col = False)

# %%
df.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
len(df)
# Out:
# 20

# %%
df.tail(35)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
vars_list = ['product_id', 'product_name', 'aisle_id', 'department_id', 'price']

# %%
vars_list
# Out:
# ['product_id', 'product_name', 'aisle_id', 'department_id', 'price']

# %%
df.shape
# Out:
# (49693, 5)

# %%
df.dtypes ['department_id']
# Out:
# dtype('int64')

# %%
# find maximum value of a
# single column 'aisle_id'
maxClm = df['aisle_id'].max()

# %%
print("Maximum value in column 'aisle_id': ")
print(maxClm)
# Out:
# Maximum value in column 'aisle_id':
# 134
